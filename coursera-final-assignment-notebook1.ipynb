# %% [markdown]
# # Clustering, Segmenting and Analyzing Neighborhoods in Ottawa, ON, the national capital city of Canada

# %% [markdown]
# ## Introduction/Business Problem
#
# In this notebook, I analyze the location data by segmenting and clustering neighborhoods in the city of Ottawa, ON - the national capital city of CANADA. The objective of this analytics is to venture out a feasiblity of establishing a small business enterprise in a particular neighborhood in the city of Ottawa. For this purpose, I am selecting a neighborhood called *Orleans-Ottawa* which is one of the fast populating neighborhoods in the capilal city. I am interested in setting up a *Bookstore* in the *Orleans* neighborhood of the city. Hence my objective would be to see whehter it is feasible to set up a *Bookstore* in the *Orleans* neighborhood or not. If there is no such enterprise already existing that neighborhood apart from other basic businesses, then I will definitely go for it.
